# %% [markdown]
# <a href="https://colab.research.google.com/github/kananshr13/CSET-343-Ai-in-Healthcare/blob/main/Lab_experiment_0_CSET_343.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
patientName = np.array(["Kanan", "Radhika", "Mehak"])
age = np.array([20, 22, 21])
id = np.array([101, 102, 103])
diagnosis = np.array(["Fever", "Cold", "Cough"])
temperature = np.array([102, 98, 99])

print("Health Report")
print("Patient Name: ", patientName)
print("Age: ", age)
print("ID: ", id)
print("Diagnosis: ", diagnosis)
print("Temperature: ", temperature)
# Out:
# Health Report
# Patient Name:  ['Kanan' 'Radhika' 'Mehak']
# Age:  [20 22 21]
# ID:  [101 102 103]
# Diagnosis:  ['Fever' 'Cold' 'Cough']
# Temperature:  [102  98  99]

# %%
data = {
    "Patient Name": patientName,
    "Age": age,
    "ID": id,
    "Diagnosis": diagnosis,
    "Temperature": temperature
}
df = pd.DataFrame(data)
print("\nPatient Data: ")
print(df)
# Out:
# Patient Data:
#   Patient Name  Age   ID Diagnosis  Temperature
# 0        Kanan   20  101     Fever          102
# 1      Radhika   22  102      Cold           98
# 2        Mehak   21  103     Cough           99

# %%
print("Statistics:")
print(df.describe())

print("Patients with temperature > 98")
print(df[df["Temperature"] > 98])
# Out:
# Statistics:
#         Age     ID  Temperature
# count   3.0    3.0     3.000000
# mean   21.0  102.0    99.666667
# std     1.0    1.0     2.081666
# min    20.0  101.0    98.000000
# 25%    20.5  101.5    98.500000
# 50%    21.0  102.0    99.000000
# 75%    21.5  102.5   100.500000
# max    22.0  103.0   102.000000
# Patients with temperature > 98
#   Patient Name  Age   ID Diagnosis  Temperature
# 0        Kanan   20  101     Fever          102
# 2        Mehak   21  103     Cough           99

# %%
df.to_csv("patient_data.csv", index=False)

new_df = pd.read_csv("patient_data.csv")

print("\nData Read from CSV:")
print(new_df)
# Out:
# Data Read from CSV:
#   Patient Name  Age   ID Diagnosis  Temperature
# 0        Kanan   20  101     Fever          102
# 1      Radhika   22  102      Cold           98
# 2        Mehak   21  103     Cough           99

# %%
plt.plot(
    df["ID"],
    df["Temperature"],
    marker="o"
)

plt.title("Temperature Analysis")
plt.xlabel("Patient ID")
plt.ylabel("Temperature")
plt.grid(True)

plt.show()

# %%
df.to_csv("patient_data.csv", index=False)

new_df = pd.read_csv("patient_data.csv")

print("\nData Read from CSV:")
print(new_df)
# Out:
# Data Read from CSV:
#   Patient Name  Age   ID Diagnosis  Temperature
# 0        Kanan   20  101     Fever          102
# 1      Radhika   22  102      Cold           98
# 2        Mehak   21  103     Cough           99

# %%
diagnosis_counts = df["Diagnosis"].value_counts()

plt.figure(figsize=(6, 6))

plt.pie(
    diagnosis_counts,
    labels=diagnosis_counts.index,
    autopct="%1.1f%%",
    startangle=90
)

plt.title("Patient Diagnosis Distribution")
plt.show()

# %%
plt.figure(figsize=(8, 5))

plt.bar(
    df["ID"],
    df["Temperature"]
)

plt.title("Temperature of Patients")
plt.xlabel("ID")
plt.ylabel("Temperature")

plt.show()
